# %%
# Import pip
import pip

# Define packages to install
packages = ['scipy']

# Define install function
def install(packages):
    for package in packages:
        pip.main(['install', package])
        
# Install packages
install(packages)
# Out:
# Downloading/unpacking scipy
# Downloading/unpacking scipy
#   Running setup.py (path:/tmp/pip_build_root/scipy/setup.py) egg_info for package scipy
#   Running setup.py (path:/tmp/pip_build_root/scipy/setup.py) egg_info for package scipy
#     Running from numpy source directory.
#     Running from numpy source directory.
#     /tmp/easy_install-3_H80f/numpy-1.11.2rc1/setup.py:327: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates
#     /tmp/easy_install-3_H80f/numpy-1.11.2rc1/setup.py:327: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates
#       warnings.warn("Unrecognized setuptools command, proceeding with "
#       warnings.warn("Unrecognized setuptools command, proceeding with "
#     /tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/system_info.py:1630: UserWarning:
#     /tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/system_info.py:1630: UserWarning:
#         Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#         Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [atlas]) or by setting
#         numpy/distutils/site.cfg file (section [atlas]) or by setting
#         the ATLAS environment variable.
#         the ATLAS environment variable.
#       warnings.warn(AtlasNotFoundError.__doc__)
#       warnings.warn(AtlasNotFoundError.__doc__)
#     /usr/bin/ld: cannot find -lcblas
#     /usr/bin/ld: cannot find -lcblas
#     collect2: error: ld returned 1 exit status
#     collect2: error: ld returned 1 exit status
#     /bin/sh: 1: svnversion: not found
#     /bin/sh: 1: svnversion: not found
#     /bin/sh: 1: svnversion: not found
#     /bin/sh: 1: svnversion: not found
#     /tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/system_info.py:1532: UserWarning:
#     /tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/system_info.py:1532: UserWarning:
#         Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#         Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [atlas]) or by setting
#         numpy/distutils/site.cfg file (section [atlas]) or by setting
#         the ATLAS environment variable.
#         the ATLAS environment variable.
#       warnings.warn(AtlasNotFoundError.__doc__)
#       warnings.warn(AtlasNotFoundError.__doc__)
#     /usr/lib/python2.7/distutils/dist.py:267: UserWarning: Unknown distribution option: 'define_macros'
#     /usr/lib/python2.7/distutils/dist.py:267: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#       warnings.warn(msg)
#     _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’ [enabled by default]
#     _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’ [enabled by default]
#      int exp (void);
#      int exp (void);
#          ^
#          ^
#     _configtest.o: In function `main':
#     _configtest.o: In function `main':
#     /tmp/easy_install-3_H80f/numpy-1.11.2rc1/_configtest.c:6: undefined reference to `exp'
#     /tmp/easy_install-3_H80f/numpy-1.11.2rc1/_configtest.c:6: undefined reference to `exp'
#     collect2: error: ld returned 1 exit status
#     collect2: error: ld returned 1 exit status
#     _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’ [enabled by default]
#     _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’ [enabled by default]
#      int exp (void);
#      int exp (void);
#          ^
#          ^
#     _configtest.c:1:20: fatal error: Python.h: No such file or directory
#     _configtest.c:1:20: fatal error: Python.h: No such file or directory
#      #include <Python.h>
#      #include <Python.h>
#                         ^
#                         ^
#     compilation terminated.
#     compilation terminated.
#     /usr/bin/ld: cannot find -lcblas
#     /usr/bin/ld: cannot find -lcblas
#     collect2: error: ld returned 1 exit status
#     collect2: error: ld returned 1 exit status
#     non-existing path in 'numpy/distutils': 'site.cfg'
#     non-existing path in 'numpy/distutils': 'site.cfg'
#     _configtest.o: In function `main':
#     _configtest.o: In function `main':
#     /tmp/easy_install-3_H80f/numpy-1.11.2rc1/_configtest.c:6: undefined reference to `exp'
#     /tmp/easy_install-3_H80f/numpy-1.11.2rc1/_configtest.c:6: undefined reference to `exp'
#     collect2: error: ld returned 1 exit status
#     collect2: error: ld returned 1 exit status
#     _configtest.c:1:20: fatal error: Python.h: No such file or directory
#     _configtest.c:1:20: fatal error: Python.h: No such file or directory
#      #include <Python.h>
#      #include <Python.h>
#                         ^
#                         ^
#     compilation terminated.
#     compilation terminated.
#     Traceback (most recent call last):
#     Traceback (most recent call last):
#       File "<string>", line 17, in <module>
#       File "<string>", line 17, in <module>
#       File "/tmp/pip_build_root/scipy/setup.py", line 415, in <module>
#       File "/tmp/pip_build_root/scipy/setup.py", line 415, in <module>
#         setup_package()
#         setup_package()
#       File "/tmp/pip_build_root/scipy/setup.py", line 411, in setup_package
#       File "/tmp/pip_build_root/scipy/setup.py", line 411, in setup_package
#         setup(**metadata)
#         setup(**metadata)
#       File "/usr/lib/python2.7/distutils/core.py", line 111, in setup
#       File "/usr/lib/python2.7/distutils/core.py", line 111, in setup
#         _setup_distribution = dist = klass(attrs)
#         _setup_distribution = dist = klass(attrs)
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/dist.py", line 315, in __init__
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/dist.py", line 315, in __init__
#         self.fetch_build_eggs(attrs['setup_requires'])
#         self.fetch_build_eggs(attrs['setup_requires'])
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/dist.py", line 361, in fetch_build_eggs
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/dist.py", line 361, in fetch_build_eggs
#         replace_conflicting=True,
#         replace_conflicting=True,
#       File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 851, in resolve
#       File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 851, in resolve
#         dist = best[req.key] = env.best_match(req, ws, installer)
#         dist = best[req.key] = env.best_match(req, ws, installer)
#       File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 1123, in best_match
#       File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 1123, in best_match
#         return self.obtain(req, installer)
#         return self.obtain(req, installer)
#       File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 1135, in obtain
#       File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 1135, in obtain
#         return installer(requirement)
#         return installer(requirement)
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/dist.py", line 429, in fetch_build_egg
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/dist.py", line 429, in fetch_build_egg
#         return cmd.easy_install(req)
#         return cmd.easy_install(req)
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 665, in easy_install
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 665, in easy_install
#         return self.install_item(spec, dist.location, tmpdir, deps)
#         return self.install_item(spec, dist.location, tmpdir, deps)
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 695, in install_item
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 695, in install_item
#         dists = self.install_eggs(spec, download, tmpdir)
#         dists = self.install_eggs(spec, download, tmpdir)
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 876, in install_eggs
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 876, in install_eggs
#         return self.build_and_install(setup_script, setup_base)
#         return self.build_and_install(setup_script, setup_base)
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 1115, in build_and_install
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 1115, in build_and_install
#         self.run_setup(setup_script, setup_base, args)
#         self.run_setup(setup_script, setup_base, args)
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 1101, in run_setup
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 1101, in run_setup
#         run_setup(setup_script, args)
#         run_setup(setup_script, args)
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 249, in run_setup
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 249, in run_setup
#         raise
#         raise
#       File "/usr/lib/python2.7/contextlib.py", line 35, in __exit__
#       File "/usr/lib/python2.7/contextlib.py", line 35, in __exit__
#         self.gen.throw(type, value, traceback)
#         self.gen.throw(type, value, traceback)
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 197, in setup_context
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 197, in setup_context
#         yield
#         yield
#       File "/usr/lib/python2.7/contextlib.py", line 35, in __exit__
#       File "/usr/lib/python2.7/contextlib.py", line 35, in __exit__
#         self.gen.throw(type, value, traceback)
#         self.gen.throw(type, value, traceback)
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 168, in save_modules
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 168, in save_modules
#         saved_exc.resume()
#         saved_exc.resume()
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 143, in resume
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 143, in resume
#         six.reraise(type, exc, self._tb)
#         six.reraise(type, exc, self._tb)
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 156, in save_modules
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 156, in save_modules
#         yield saved
#         yield saved
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 197, in setup_context
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 197, in setup_context
#         yield
#         yield
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 246, in run_setup
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 246, in run_setup
#         DirectorySandbox(setup_dir).run(runner)
#         DirectorySandbox(setup_dir).run(runner)
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 276, in run
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 276, in run
#         return func()
#         return func()
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 245, in runner
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 245, in runner
#         _execfile(setup_script, ns)
#         _execfile(setup_script, ns)
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 47, in _execfile
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 47, in _execfile
#         exec(code, globals, locals)
#         exec(code, globals, locals)
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/setup.py", line 386, in <module>
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/setup.py", line 386, in <module>
#         # Raise errors for unsupported commands, improve help output, etc.
#         # Raise errors for unsupported commands, improve help output, etc.
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/setup.py", line 378, in setup_package
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/setup.py", line 378, in setup_package
#         test_suite='nose.collector',
#         test_suite='nose.collector',
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/core.py", line 169, in setup
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/core.py", line 169, in setup
#       File "/usr/lib/python2.7/distutils/core.py", line 151, in setup
#       File "/usr/lib/python2.7/distutils/core.py", line 151, in setup
#         dist.run_commands()
#         dist.run_commands()
#       File "/usr/lib/python2.7/distutils/dist.py", line 953, in run_commands
#       File "/usr/lib/python2.7/distutils/dist.py", line 953, in run_commands
#         self.run_command(cmd)
#         self.run_command(cmd)
#       File "/usr/lib/python2.7/distutils/dist.py", line 972, in run_command
#       File "/usr/lib/python2.7/distutils/dist.py", line 972, in run_command
#         cmd_obj.run()
#         cmd_obj.run()
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/command/bdist_egg.py", line 152, in run
#       File "/usr/local/lib/python2.7/dist-packages/setuptools/command/bdist_egg.py", line 152, in run
#         self.run_command("egg_info")
#         self.run_command("egg_info")
#       File "/usr/lib/python2.7/distutils/cmd.py", line 326, in run_command
#       File "/usr/lib/python2.7/distutils/cmd.py", line 326, in run_command
#         self.distribution.run_command(command)
#         self.distribution.run_command(command)
#       File "/usr/lib/python2.7/distutils/dist.py", line 972, in run_command
#       File "/usr/lib/python2.7/distutils/dist.py", line 972, in run_command
#         cmd_obj.run()
#         cmd_obj.run()
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/egg_info.py", line 18, in run
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/egg_info.py", line 18, in run
#       File "/usr/lib/python2.7/distutils/cmd.py", line 326, in run_command
#       File "/usr/lib/python2.7/distutils/cmd.py", line 326, in run_command
#         self.distribution.run_command(command)
#         self.distribution.run_command(command)
#       File "/usr/lib/python2.7/distutils/dist.py", line 972, in run_command
#       File "/usr/lib/python2.7/distutils/dist.py", line 972, in run_command
#         cmd_obj.run()
#         cmd_obj.run()
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 147, in run
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 147, in run
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 164, in build_sources
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 164, in build_sources
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 323, in build_extension_sources
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 323, in build_extension_sources
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 376, in generate_sources
#       File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 376, in generate_sources
#       File "numpy/core/setup.py", line 407, in generate_config_h
#       File "numpy/core/setup.py", line 407, in generate_config_h
#         # Version number is added to metadata inside configuration() if build
#         # Version number is added to metadata inside configuration() if build
#       File "numpy/core/setup.py", line 40, in check_types
#       File "numpy/core/setup.py", line 40, in check_types
#         License :: OSI Approved :: BSD License
#         License :: OSI Approved :: BSD License
#       File "numpy/core/setup.py", line 269, in check_types
#       File "numpy/core/setup.py", line 269, in check_types
#         into a bug, please report it at https://github.com/scipy/scipy/issues.
#         into a bug, please report it at https://github.com/scipy/scipy/issues.
#     SystemError: Cannot compile 'Python.h'. Perhaps you need to install python-dev|python-devel.
#     SystemError: Cannot compile 'Python.h'. Perhaps you need to install python-dev|python-devel.
#     Complete output from command python setup.py egg_info:
#     Complete output from command python setup.py egg_info:
#     Running from numpy source directory.
#
# /tmp/easy_install-3_H80f/numpy-1.11.2rc1/setup.py:327: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates
#
#   warnings.warn("Unrecognized setuptools command, proceeding with "
#
# /tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/system_info.py:1630: UserWarning:
#
#     Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#
#     Directories to search for the libraries can be specified in the
#
#     numpy/distutils/site.cfg file (section [atlas]) or by setting
#
#     the ATLAS environment variable.
#
#   warnings.warn(AtlasNotFoundError.__doc__)
#
# /usr/bin/ld: cannot find -lcblas
#
# collect2: error: ld returned 1 exit status
#
# /bin/sh: 1: svnversion: not found
#
# /bin/sh: 1: svnversion: not found
#
# /tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/system_info.py:1532: UserWarning:
#
#     Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#
#     Directories to search for the libraries can be specified in the
#
#     numpy/distutils/site.cfg file (section [atlas]) or by setting
#
#     the ATLAS environment variable.
#
#   warnings.warn(AtlasNotFoundError.__doc__)
#
# /usr/lib/python2.7/distutils/dist.py:267: UserWarning: Unknown distribution option: 'define_macros'
#
#   warnings.warn(msg)
#
# _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’ [enabled by default]
#
#  int exp (void);
#
#      ^
#
# _configtest.o: In function `main':
#
# /tmp/easy_install-3_H80f/numpy-1.11.2rc1/_configtest.c:6: undefined reference to `exp'
#
# collect2: error: ld returned 1 exit status
#
# _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’ [enabled by default]
#
#  int exp (void);
#
#      ^
#
# _configtest.c:1:20: fatal error: Python.h: No such file or directory
#
#  #include <Python.h>
#
#                     ^
#
# compilation terminated.
#
# /usr/bin/ld: cannot find -lcblas
#
# collect2: error: ld returned 1 exit status
#
# non-existing path in 'numpy/distutils': 'site.cfg'
#
# _configtest.o: In function `main':
#
# /tmp/easy_install-3_H80f/numpy-1.11.2rc1/_configtest.c:6: undefined reference to `exp'
#
# collect2: error: ld returned 1 exit status
#
# _configtest.c:1:20: fatal error: Python.h: No such file or directory
#
#  #include <Python.h>
#
#                     ^
#
# compilation terminated.
#
# Traceback (most recent call last):
#
#   File "<string>", line 17, in <module>
#
#   File "/tmp/pip_build_root/scipy/setup.py", line 415, in <module>
#
#     setup_package()
#
#   File "/tmp/pip_build_root/scipy/setup.py", line 411, in setup_package
#
#     setup(**metadata)
#
#   File "/usr/lib/python2.7/distutils/core.py", line 111, in setup
#
#     _setup_distribution = dist = klass(attrs)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/dist.py", line 315, in __init__
#
#     self.fetch_build_eggs(attrs['setup_requires'])
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/dist.py", line 361, in fetch_build_eggs
#
#     replace_conflicting=True,
#
#   File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 851, in resolve
#
#     dist = best[req.key] = env.best_match(req, ws, installer)
#
#   File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 1123, in best_match
#
#     return self.obtain(req, installer)
#
#   File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 1135, in obtain
#
#     return installer(requirement)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/dist.py", line 429, in fetch_build_egg
#
#     return cmd.easy_install(req)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 665, in easy_install
#
#     return self.install_item(spec, dist.location, tmpdir, deps)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 695, in install_item
#
#     dists = self.install_eggs(spec, download, tmpdir)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 876, in install_eggs
#
#     return self.build_and_install(setup_script, setup_base)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 1115, in build_and_install
#
#     self.run_setup(setup_script, setup_base, args)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 1101, in run_setup
#
#     run_setup(setup_script, args)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 249, in run_setup
#
#     raise
#
#   File "/usr/lib/python2.7/contextlib.py", line 35, in __exit__
#
#     self.gen.throw(type, value, traceback)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 197, in setup_context
#
#     yield
#
#   File "/usr/lib/python2.7/contextlib.py", line 35, in __exit__
#
#     self.gen.throw(type, value, traceback)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 168, in save_modules
#
#     saved_exc.resume()
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 143, in resume
#
#     six.reraise(type, exc, self._tb)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 156, in save_modules
#
#     yield saved
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 197, in setup_context
#
#     yield
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 246, in run_setup
#
#     DirectorySandbox(setup_dir).run(runner)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 276, in run
#
#     return func()
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 245, in runner
#
#     _execfile(setup_script, ns)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 47, in _execfile
#
#     exec(code, globals, locals)
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/setup.py", line 386, in <module>
#
#     # Raise errors for unsupported commands, improve help output, etc.
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/setup.py", line 378, in setup_package
#
#     test_suite='nose.collector',
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/core.py", line 169, in setup
#
#   File "/usr/lib/python2.7/distutils/core.py", line 151, in setup
#
#     dist.run_commands()
#
#   File "/usr/lib/python2.7/distutils/dist.py", line 953, in run_commands
#
#     self.run_command(cmd)
#
#   File "/usr/lib/python2.7/distutils/dist.py", line 972, in run_command
#
#     cmd_obj.run()
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/command/bdist_egg.py", line 152, in run
#
#     self.run_command("egg_info")
#
#   File "/usr/lib/python2.7/distutils/cmd.py", line 326, in run_command
#
#     self.distribution.run_command(command)
#
#   File "/usr/lib/python2.7/distutils/dist.py", line 972, in run_command
#
#     cmd_obj.run()
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/egg_info.py", line 18, in run
#
#   File "/usr/lib/python2.7/distutils/cmd.py", line 326, in run_command
#
#     self.distribution.run_command(command)
#
#   File "/usr/lib/python2.7/distutils/dist.py", line 972, in run_command
#
#     cmd_obj.run()
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 147, in run
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 164, in build_sources
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 323, in build_extension_sources
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 376, in generate_sources
#
#   File "numpy/core/setup.py", line 407, in generate_config_h
#
#     # Version number is added to metadata inside configuration() if build
#
#   File "numpy/core/setup.py", line 40, in check_types
#
#     License :: OSI Approved :: BSD License
#
#   File "numpy/core/setup.py", line 269, in check_types
#
#     into a bug, please report it at https://github.com/scipy/scipy/issues.
#
# SystemError: Cannot compile 'Python.h'. Perhaps you need to install python-dev|python-devel.
#
# ----------------------------------------
#     Running from numpy source directory.
#
# /tmp/easy_install-3_H80f/numpy-1.11.2rc1/setup.py:327: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates
#
#   warnings.warn("Unrecognized setuptools command, proceeding with "
#
# /tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/system_info.py:1630: UserWarning:
#
#     Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#
#     Directories to search for the libraries can be specified in the
#
#     numpy/distutils/site.cfg file (section [atlas]) or by setting
#
#     the ATLAS environment variable.
#
#   warnings.warn(AtlasNotFoundError.__doc__)
#
# /usr/bin/ld: cannot find -lcblas
#
# collect2: error: ld returned 1 exit status
#
# /bin/sh: 1: svnversion: not found
#
# /bin/sh: 1: svnversion: not found
#
# /tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/system_info.py:1532: UserWarning:
#
#     Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#
#     Directories to search for the libraries can be specified in the
#
#     numpy/distutils/site.cfg file (section [atlas]) or by setting
#
#     the ATLAS environment variable.
#
#   warnings.warn(AtlasNotFoundError.__doc__)
#
# /usr/lib/python2.7/distutils/dist.py:267: UserWarning: Unknown distribution option: 'define_macros'
#
#   warnings.warn(msg)
#
# _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’ [enabled by default]
#
#  int exp (void);
#
#      ^
#
# _configtest.o: In function `main':
#
# /tmp/easy_install-3_H80f/numpy-1.11.2rc1/_configtest.c:6: undefined reference to `exp'
#
# collect2: error: ld returned 1 exit status
#
# _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’ [enabled by default]
#
#  int exp (void);
#
#      ^
#
# _configtest.c:1:20: fatal error: Python.h: No such file or directory
#
#  #include <Python.h>
#
#                     ^
#
# compilation terminated.
#
# /usr/bin/ld: cannot find -lcblas
#
# collect2: error: ld returned 1 exit status
#
# non-existing path in 'numpy/distutils': 'site.cfg'
#
# _configtest.o: In function `main':
#
# /tmp/easy_install-3_H80f/numpy-1.11.2rc1/_configtest.c:6: undefined reference to `exp'
#
# collect2: error: ld returned 1 exit status
#
# _configtest.c:1:20: fatal error: Python.h: No such file or directory
#
#  #include <Python.h>
#
#                     ^
#
# compilation terminated.
#
# Traceback (most recent call last):
#
#   File "<string>", line 17, in <module>
#
#   File "/tmp/pip_build_root/scipy/setup.py", line 415, in <module>
#
#     setup_package()
#
#   File "/tmp/pip_build_root/scipy/setup.py", line 411, in setup_package
#
#     setup(**metadata)
#
#   File "/usr/lib/python2.7/distutils/core.py", line 111, in setup
#
#     _setup_distribution = dist = klass(attrs)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/dist.py", line 315, in __init__
#
#     self.fetch_build_eggs(attrs['setup_requires'])
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/dist.py", line 361, in fetch_build_eggs
#
#     replace_conflicting=True,
#
#   File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 851, in resolve
#
#     dist = best[req.key] = env.best_match(req, ws, installer)
#
#   File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 1123, in best_match
#
#     return self.obtain(req, installer)
#
#   File "/usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py", line 1135, in obtain
#
#     return installer(requirement)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/dist.py", line 429, in fetch_build_egg
#
#     return cmd.easy_install(req)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 665, in easy_install
#
#     return self.install_item(spec, dist.location, tmpdir, deps)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 695, in install_item
#
#     dists = self.install_eggs(spec, download, tmpdir)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 876, in install_eggs
#
#     return self.build_and_install(setup_script, setup_base)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 1115, in build_and_install
#
#     self.run_setup(setup_script, setup_base, args)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/command/easy_install.py", line 1101, in run_setup
#
#     run_setup(setup_script, args)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 249, in run_setup
#
#     raise
#
#   File "/usr/lib/python2.7/contextlib.py", line 35, in __exit__
#
#     self.gen.throw(type, value, traceback)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 197, in setup_context
#
#     yield
#
#   File "/usr/lib/python2.7/contextlib.py", line 35, in __exit__
#
#     self.gen.throw(type, value, traceback)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 168, in save_modules
#
#     saved_exc.resume()
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 143, in resume
#
#     six.reraise(type, exc, self._tb)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 156, in save_modules
#
#     yield saved
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 197, in setup_context
#
#     yield
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 246, in run_setup
#
#     DirectorySandbox(setup_dir).run(runner)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 276, in run
#
#     return func()
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 245, in runner
#
#     _execfile(setup_script, ns)
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/sandbox.py", line 47, in _execfile
#
#     exec(code, globals, locals)
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/setup.py", line 386, in <module>
#
#     # Raise errors for unsupported commands, improve help output, etc.
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/setup.py", line 378, in setup_package
#
#     test_suite='nose.collector',
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/core.py", line 169, in setup
#
#   File "/usr/lib/python2.7/distutils/core.py", line 151, in setup
#
#     dist.run_commands()
#
#   File "/usr/lib/python2.7/distutils/dist.py", line 953, in run_commands
#
#     self.run_command(cmd)
#
#   File "/usr/lib/python2.7/distutils/dist.py", line 972, in run_command
#
#     cmd_obj.run()
#
#   File "/usr/local/lib/python2.7/dist-packages/setuptools/command/bdist_egg.py", line 152, in run
#
#     self.run_command("egg_info")
#
#   File "/usr/lib/python2.7/distutils/cmd.py", line 326, in run_command
#
#     self.distribution.run_command(command)
#
#   File "/usr/lib/python2.7/distutils/dist.py", line 972, in run_command
#
#     cmd_obj.run()
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/egg_info.py", line 18, in run
#
#   File "/usr/lib/python2.7/distutils/cmd.py", line 326, in run_command
#
#     self.distribution.run_command(command)
#
#   File "/usr/lib/python2.7/distutils/dist.py", line 972, in run_command
#
#     cmd_obj.run()
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 147, in run
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 164, in build_sources
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 323, in build_extension_sources
#
#   File "/tmp/easy_install-3_H80f/numpy-1.11.2rc1/numpy/distutils/command/build_src.py", line 376, in generate_sources
#
#   File "numpy/core/setup.py", line 407, in generate_config_h
#
#     # Version number is added to metadata inside configuration() if build
#
#   File "numpy/core/setup.py", line 40, in check_types
#
#     License :: OSI Approved :: BSD License
#
#   File "numpy/core/setup.py", line 269, in check_types
#
#     into a bug, please report it at https://github.com/scipy/scipy/issues.
#
# SystemError: Cannot compile 'Python.h'. Perhaps you need to install python-dev|python-devel.
#
# ----------------------------------------
# Cleaning up...
# Cleaning up...
# Command python setup.py egg_info failed with error code 1 in /tmp/pip_build_root/scipy
# Command python setup.py egg_info failed with error code 1 in /tmp/pip_build_root/scipy
# UnicodeDecodeErrorTraceback (most recent call last)
# <ipython-input-2-a27a186c18dc> in <module>()
#      11
#      12 # Install packages
# ---> 13 install(packages)
#
# <ipython-input-2-a27a186c18dc> in install(packages)
#       8 def install(packages):
#       9     for package in packages:
# ---> 10         pip.main(['install', package])
#      11
#      12 # Install packages
#
# /usr/lib/python2.7/dist-packages/pip/__init__.pyc in main(initial_args)
#     233
#     234     command = commands[cmd_name]()
# --> 235     return command.main(cmd_args)
#     236
#     237
#
# /usr/lib/python2.7/dist-packages/pip/basecommand.pyc in main(self, args)
#     159         if store_log:
#     160             log_file_fn = options.log_file
# --> 161             text = '\n'.join(complete_log)
#     162             try:
#     163                 log_file_fp = open_logfile(log_file_fn, 'w')
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe2 in position 72: ordinal not in range(128)
